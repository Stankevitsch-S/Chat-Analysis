# %%
# Imports
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense,Dropout
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
import ast

# %%
# Loading the data set.
gameDf = pd.read_csv('gameDf.csv')

# %%
# The csv has the list of chat messages as a single string. This function recovers the python list.
gameDf['chatsclean'] = gameDf['chatsclean'].apply(ast.literal_eval)

# %%
# BoW encoding, text has already been processed.
vectorizer = CountVectorizer(tokenizer=lambda x: x, preprocessor=lambda x: x,lowercase=False)

# %%
# Creating machine learning matricies and performing train-test split for validation.
X = vectorizer.fit_transform(gameDf['chatsclean'].tolist()).toarray()
y = gameDf['result'].to_numpy()
XTrain, XTest, yTrain, yTest = train_test_split(X,y,random_state=42)

# %%
# Building the neural network layers, one layer with 50% dropout.
model = Sequential()
model.add(Dense(16, input_dim=X.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# %%
# Compiling the model, I included accuracy to get a quick glance at model performance when fitting.
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# A callback function to stop training when validation set loss begins to increase to prevent overfitting.
es = EarlyStopping(monitor='val_loss',min_delta=0,patience=2,verbose=0, mode='auto')

# %%
# Fitting the neural network using the same train/test data as the other models.
model.fit(XTrain, yTrain, validation_data=(XTest,yTest), epochs=50, batch_size=32, callbacks=es)
# Out:
# Epoch 1/50
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6981 - accuracy: 0.4536 - val_loss: 0.6911 - val_accuracy: 0.6383
# Epoch 2/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6942 - accuracy: 0.5393 - val_loss: 0.6900 - val_accuracy: 0.6596
# Epoch 3/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6795 - accuracy: 0.5929 - val_loss: 0.6893 - val_accuracy: 0.6383
# Epoch 4/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6722 - accuracy: 0.6214 - val_loss: 0.6888 - val_accuracy: 0.6277
# Epoch 5/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6677 - accuracy: 0.6143 - val_loss: 0.6879 - val_accuracy: 0.6383
# Epoch 6/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6612 - accuracy: 0.6321 - val_loss: 0.6868 - val_accuracy: 0.6383
# Epoch 7/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6533 - accuracy: 0.6321 - val_loss: 0.6856 - val_accuracy: 0.6277
# Epoch 8/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6460 - accuracy: 0.6714 - val_loss: 0.6843 - val_accuracy: 0.6064
# Epoch 9/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6387 - accuracy: 0.6536 - val_loss: 0.6835 - val_accuracy: 0.6383
# Epoch 10/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6285 - accuracy: 0.7143 - val_loss: 0.6821 - val_accuracy: 0.6383
# Epoch 11/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6270 - accuracy: 0.6893 - val_loss: 0.6811 - val_accuracy: 0.6383
# Epoch 12/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6126 - accuracy: 0.7071 - val_loss: 0.6799 - val_accuracy: 0.6170
# Epoch 13/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6155 - accuracy: 0.6857 - val_loss: 0.6792 - val_accuracy: 0.6170
# Epoch 14/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6009 - accuracy: 0.7607 - val_loss: 0.6782 - val_accuracy: 0.6277
# Epoch 15/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5906 - accuracy: 0.7143 - val_loss: 0.6774 - val_accuracy: 0.6383
# Epoch 16/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5839 - accuracy: 0.7536 - val_loss: 0.6764 - val_accuracy: 0.6277
# Epoch 17/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5721 - accuracy: 0.7679 - val_loss: 0.6753 - val_accuracy: 0.6383
# Epoch 18/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5748 - accuracy: 0.7643 - val_loss: 0.6747 - val_accuracy: 0.6170
# Epoch 19/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5557 - accuracy: 0.7786 - val_loss: 0.6745 - val_accuracy: 0.6277
# Epoch 20/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5442 - accuracy: 0.8000 - val_loss: 0.6738 - val_accuracy: 0.6170
# Epoch 21/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5336 - accuracy: 0.8143 - val_loss: 0.6733 - val_accuracy: 0.6064
# Epoch 22/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5288 - accuracy: 0.7786 - val_loss: 0.6728 - val_accuracy: 0.6064
# Epoch 23/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5358 - accuracy: 0.7750 - val_loss: 0.6713 - val_accuracy: 0.6064
# Epoch 24/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5124 - accuracy: 0.8107 - val_loss: 0.6696 - val_accuracy: 0.6064
# Epoch 25/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5074 - accuracy: 0.8000 - val_loss: 0.6695 - val_accuracy: 0.6277
# Epoch 26/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4878 - accuracy: 0.8143 - val_loss: 0.6691 - val_accuracy: 0.6277
# Epoch 27/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4935 - accuracy: 0.8071 - val_loss: 0.6690 - val_accuracy: 0.6170
# Epoch 28/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4834 - accuracy: 0.7929 - val_loss: 0.6687 - val_accuracy: 0.6170
# Epoch 29/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4705 - accuracy: 0.8143 - val_loss: 0.6691 - val_accuracy: 0.6170
# Epoch 30/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4608 - accuracy: 0.8179 - val_loss: 0.6689 - val_accuracy: 0.6170

# %%
# Classification report to compare f1-score to other models.
print(classification_report(yTest, np.round(model.predict(XTest))))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.45      0.51        42
#            1       0.63      0.75      0.68        52
#
#     accuracy                           0.62        94
#    macro avg       0.61      0.60      0.60        94
# weighted avg       0.61      0.62      0.61        94

# %%
# Fraction of "win" predictions.
sum(np.round(model.predict(XTest)))/len(np.round(model.predict(XTest)))
# Out:
# array([0.65957445], dtype=float32)
